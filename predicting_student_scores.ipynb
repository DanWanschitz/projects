# %%
#importing the necessary libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error

# %%
#import the training and testing set
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
#inspect the training set
train.info()
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                630000 non-null  int64
#  1   age               630000 non-null  int64
#  2   gender            630000 non-null  object
#  3   course            630000 non-null  object
#  4   study_hours       630000 non-null  float64
#  5   class_attendance  630000 non-null  float64
#  6   internet_access   630000 non-null  object
#  7   sleep_hours       630000 non-null  float64
#  8   sleep_quality     630000 non-null  object
#  9   study_method      630000 non-null  object
#  10  facility_rating   630000 non-null  object
#  11  exam_difficulty   630000 non-null  object
#  12  exam_score        630000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 62.5+ MB
#    id  age  gender   course  study_hours  class_attendance internet_access  \
# 0   0   21  female     b.sc         7.91              98.8              no
# 1   1   18   other  diploma         4.95              94.8             yes
# 2   2   20  female     b.sc         4.68              92.6             yes
# 3   3   19    male     b.sc         2.00              49.5             yes
# 4   4   23    male      bca         7.65              86.9             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0          4.9       average  online videos             low            easy
# 1          4.7          poor     self-study          medium        moderate
# 2          5.8          poor       coaching            high        moderate
# 3          8.3       average    group study            high        moderate
# 4          9.6          good     self-study            high            easy
#
#    exam_score
# 0        78.3
# 1        46.7
# 2        99.0
# 3        63.9
# 4       100.0

# %%
#inspecting the test set
test.info()
test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270000 entries, 0 to 269999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                270000 non-null  int64
#  1   age               270000 non-null  int64
#  2   gender            270000 non-null  object
#  3   course            270000 non-null  object
#  4   study_hours       270000 non-null  float64
#  5   class_attendance  270000 non-null  float64
#  6   internet_access   270000 non-null  object
#  7   sleep_hours       270000 non-null  float64
#  8   sleep_quality     270000 non-null  object
#  9   study_method      270000 non-null  object
#  10  facility_rating   270000 non-null  object
#  11  exam_difficulty   270000 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 24.7+ MB
#        id  age  gender   course  study_hours  class_attendance  \
# 0  630000   24   other       ba         6.85              65.2
# 1  630001   18    male  diploma         6.61              45.0
# 2  630002   24  female   b.tech         6.60              98.5
# 3  630003   24    male  diploma         3.03              66.3
# 4  630004   20  female   b.tech         2.03              42.4
#
#   internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 0             yes          5.2          poor  group study            high
# 1              no          9.3          poor     coaching             low
# 2             yes          6.2          good  group study          medium
# 3             yes          5.7       average        mixed          medium
# 4             yes          9.2       average     coaching             low
#
#   exam_difficulty
# 0            easy
# 1            easy
# 2        moderate
# 3        moderate
# 4        moderate

# %%
categorical_columns = train[[
    'gender', 'course', 'internet_access', 'sleep_quality', 'study_method', 'facility_rating', 'exam_difficulty'
]]

for col in categorical_columns:
    label_encoder = LabelEncoder()
    train[col] = label_encoder.fit_transform(train[col])

train
# Out:
#             id  age  gender  course  study_hours  class_attendance  \
# 0            0   21       0       1         7.91              98.8
# 1            1   18       2       6         4.95              94.8
# 2            2   20       0       1         4.68              92.6
# 3            3   19       1       1         2.00              49.5
# 4            4   23       1       5         7.65              86.9
# ...        ...  ...     ...     ...          ...               ...
# 629995  629995   18       0       2         4.86              70.7
# 629996  629996   21       0       3         7.08              54.4
# 629997  629997   24       1       5         0.64              44.2
# 629998  629998   20       1       0         1.54              75.1
# 629999  629999   18       2       2         3.94              75.3
#
#         internet_access  sleep_hours  sleep_quality  study_method  \
# 0                     0          4.9              0             3
# 1                     1          4.7              2             4
# 2                     1          5.8              2             0
# 3                     1          8.3              0             1
# 4                     1          9.6              1             4
# ...                 ...          ...            ...           ...
# 629995                1          4.1              1             2
# 629996                1          4.5              0             2
# 629997                1          4.3              2             3
# 629998                1          8.2              0             1
# 629999                1          5.8              2             3
#
#         facility_rating  exam_difficulty  exam_score
# 0                     1                0      78.300
# 1                     2                2      46.700
# 2                     0                2      99.000
# 3                     0                2      63.900
# 4                     0                0     100.000
# ...                 ...              ...         ...
# 629995                0                2      69.500
# 629996                1                2      78.900
# 629997                1                2      19.599
# 629998                0                2      59.100
# 629999                1                0      37.200
#
# [630000 rows x 13 columns]

# %%
#correlation matrix 
corr_matrix = train.corr()
corr_matrix_exam = (
    corr_matrix['exam_score'].sort_values(ascending=False)
)

print(corr_matrix_exam)
# Out:
# exam_score          1.000000
# study_hours         0.762267
# class_attendance    0.360954
# sleep_hours         0.167410
# age                 0.010472
# exam_difficulty     0.008337
# gender              0.004748
# course              0.003874
# internet_access     0.000447
# id                  0.000372
# facility_rating    -0.076605
# sleep_quality      -0.124749
# study_method       -0.183431
# Name: exam_score, dtype: float64

# %%
categorical_columns = test[[
    'gender', 'course', 'internet_access', 'sleep_quality', 'study_method', 'facility_rating', 'exam_difficulty'
]]

for col in categorical_columns:
    label_encoder = LabelEncoder()
    test[col] = label_encoder.fit_transform(test[col])

test
# Out:
#             id  age  gender  course  study_hours  class_attendance  \
# 0       630000   24       2       3         6.85              65.2
# 1       630001   18       1       6         6.61              45.0
# 2       630002   24       0       2         6.60              98.5
# 3       630003   24       1       6         3.03              66.3
# 4       630004   20       0       2         2.03              42.4
# ...        ...  ...     ...     ...          ...               ...
# 269995  899995   21       2       0         2.55              82.3
# 269996  899996   17       0       0         0.49              46.4
# 269997  899997   22       1       4         6.62              74.7
# 269998  899998   22       2       3         4.08              51.8
# 269999  899999   20       0       0         5.86              59.7
#
#         internet_access  sleep_hours  sleep_quality  study_method  \
# 0                     1          5.2              2             1
# 1                     0          9.3              2             0
# 2                     1          6.2              1             1
# 3                     1          5.7              0             2
# 4                     1          9.2              0             0
# ...                 ...          ...            ...           ...
# 269995                1          8.4              0             2
# 269996                1          8.8              1             2
# 269997                1          5.5              1             0
# 269998                1          8.7              2             3
# 269999                1          8.9              2             2
#
#         facility_rating  exam_difficulty
# 0                     0                0
# 1                     1                0
# 2                     2                2
# 3                     2                2
# 4                     1                2
# ...                 ...              ...
# 269995                2                1
# 269996                1                0
# 269997                0                0
# 269998                0                2
# 269999                2                2
#
# [270000 rows x 12 columns]

# %%
features = train.drop(columns=['id', 'exam_score'])
X = features
y = train['exam_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
rmse = root_mean_squared_error(y_test, y_pred)
rmse
# Out:
# 9.93663017272596

# %%
fig, axes = plt.subplots(1, 5, figsize=(12, 5))
for i in range(5):
    sns.regplot(data=train, x=X_train.iloc[:, i], y=y_train, ax=axes[i])
    axes[i].set_xlabel(X_train.columns[i])
    axes[i].set_ylabel('exam_score')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.residplot(x=y_train, y=yhat_train, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.show()

# %%
#Model Comparison
#Gradient Boosting Regression
from sklearn import ensemble

params = {
    'n_estimators': 500,
    'max_depth': 5,
    'min_samples_split': 5,
    'learning_rate': 0.01,
    'loss': 'squared_error',
}

gradient_boosting_model = ensemble.GradientBoostingRegressor(**params)
gradient_boosting_model.fit(X_train, y_train)

rmse = root_mean_squared_error(y_test, gradient_boosting_model.predict(X_test))
print(rmse)
# Out:
# 8.876906145390459
